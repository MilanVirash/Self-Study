# %%
import pandas as pd
import numpy as np

# %%
np.random.seed(0)
HourStudies = np.random.uniform(0, 10, 1000)
ExamScore =  50 + 5*HourStudies + np.random.normal(0, 2, 1000)

# %%
df = pd.DataFrame({"HourStudies":HourStudies, "ExamScore":ExamScore})
df
# Out:
#      HourStudies  ExamScore
# 0       5.488135  77.237281
# 1       7.151894  85.798027
# 2       6.027634  83.837351
# 3       5.448832  76.815826
# 4       4.236548  70.184707
# ..           ...        ...
# 995     0.976764  54.864504
# 996     5.149222  72.151781
# 997     9.384120  95.316095
# 998     2.286466  61.818755
# 999     6.771411  86.451741
#
# [1000 rows x 2 columns]

# %%
x = df[['HourStudies']]
y = df['ExamScore']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score

MSE = mean_squared_error(y_test, y_pred)
R2 = r2_score(y_test, y_pred)

print(f'MSE : {MSE:.2f}')
print(f'R2 : {R2:.2f}')
# Out:
# MSE : 4.17
# R2 : 0.98

# %%
import matplotlib.pyplot as plt

# Plot the regression line and data points
plt.figure(figsize=(8, 5), facecolor='#EF9481')
plt.scatter(x_test, y_test, color='black', label='Actual Data')
plt.plot(x_test, y_pred, color='yellow', label='Regression Line', linewidth=2)
plt.xlabel('Hours Studied')
plt.ylabel('Exam Scores')
plt.legend()
plt.title('Simple Linear Regression: Hours Studied vs. Exam Scores')
plt.grid(True)
plt.show()
